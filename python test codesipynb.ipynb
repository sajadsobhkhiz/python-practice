# %%
print("this is from Jupyter!")
print('hello')
print('the one programmer is Sajad')

name = 'ali'
a=12
# Out:
# this is from Jupyter!
# hello
# the one programmer is Sajad

# %%
def read_file_contents(file_path):
    try:
        with open(file_path, 'r') as file:
            contents = file.read()
            print(contents)
    except FileNotFoundError:
        print("Error: File not found -", file_path)

read_file_contents("/Users/Example/Documents/my_file.txt")
# Out:
# Error: File not found - /Users/Example/Documents/my_file.txt

# %%
def calculate_discount(price, discount_percentage):
    if discount_percentage < 0 or discount_percentage > 100:
        raise ValueError("Discount percentage must be between 0 and 100")
    discount_amount = price * (discount_percentage / 100)
    discounted_price = price - discount_amount
    return discounted_price

P = 140
D = 101

try:
    print(calculate_discount(P, D))
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Error: Discount percentage must be between 0 and 100

# %%
import pytest 
def calculate_discount(price, percentage):
  return price - (price * percentage / 100)
 
class TestDiscountCalculation:
  def test_ten_percent_discount(self):
    result = calculate_discount(100, 10)
    assert result == 90  # Assertion
 
  def test_invalid_input(self):
    with pytest.raises(TypeError):
      calculate_discount("300", 10)   # Test for incorrect input type

mytest=TestDiscountCalculation()
mytest.test_invalid_input()
mytest.test_ten_percent_discount()

# %%
# Out:
# 0.4166666666666667
